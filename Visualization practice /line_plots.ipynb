# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/media/prince/5A4E832F4E83034D/Visualization practice /Data/insurance.csv')

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
Sachin =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
Kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
Sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
 
plt.plot(years, Kohli, color='red',linestyle='-.', label="Virat Kohli")
plt.plot(years, Sehwag,color='black', linestyle='-.',label="Virender Sehwag")
plt.plot(years, Sachin,color='blue', linestyle='-.',label='Sachin Tendulkar')
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.grid(True)
plt.legend()
plt.show()

# %%
df2 = df.head(20).copy()
x = df2['age']
y = df2['charges']
plt.plot(x,y)
